# %% [markdown]
# <a href="https://colab.research.google.com/github/sandrodevdariani/firstscrapper/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
from IPython.display import Image, display

# !git clone https://github.com/dvschultz/neural-style-tf
# %cd neural-style-tf/
# !pip install -r requirements.txt
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# Cloning into 'neural-style-tf'...
# remote: Enumerating objects: 925, done.
# remote: Total 925 (delta 0), reused 0 (delta 0), pack-reused 925
# Receiving objects: 100% (925/925), 85.25 MiB | 22.67 MiB/s, done.
# Resolving deltas: 100% (468/468), done.
# /content/neural-style-tf
# ...
# --2022-03-15 12:42:32--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat [following]
# --2022-03-15 12:42:33--  https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# ...

# %%
# !python neural_style.py --content_img 242_50.jpg --style_imgs kandinsky.jpg --max_size 500 --max_iterations 100
# Out:
# Traceback (most recent call last):
#   File "neural_style.py", line 889, in <module>
#     main()
#   File "neural_style.py", line 886, in main
#     else: render_single_image()
#   File "neural_style.py", line 849, in render_single_image
#     content_img = get_content_image(args.content_img)
#   File "neural_style.py", line 715, in get_content_image
#     check_image(img, path)
#   File "neural_style.py", line 552, in check_image
#     raise OSError(errno.ENOENT, "No such file", path)
# FileNotFoundError: [Errno 2] No such file: './image_input/image_output-100.png'

# %%
listOfImageNames = ['image_output/100/content.png',
                    'image_output/100/style_0.png',
                    'image_output/100/image_output-100.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))
